# %%
#Import required libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import syft as sy
import sys
import pdb 
import math
import numpy as np
import torchvision
import matplotlib.pyplot as plt
import torchvision.models as models
from random import shuffle
from torch.utils.data import SubsetRandomSampler
import torchvision.models as models
import datetime
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0322 00:00:48.841265 16072 secure_random.py:26] Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow. Fix this by compiling custom ops. Missing file was 'c:\users\florian\appdata\local\programs\python\python37\lib\site-packages\tf_encrypted-0.5.9-py3.7.egg\tf_encrypted/operations/secure_random/secure_random_module_tf_1.15.0-rc3.so'
# W0322 00:00:48.867267 16072 module_wrapper.py:139] From c:\users\florian\appdata\local\programs\python\python37\lib\site-packages\tf_encrypted-0.5.9-py3.7.egg\tf_encrypted\session.py:24: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
#original
data_transform = transforms.Compose([
        transforms.ToTensor(),                     
        transforms.Normalize(                     
            mean=[0.485, 0.456, 0.406],               
            std=[0.229, 0.224, 0.225]                  
        )])

#horizontal
data_transform = transforms.Compose([
       transforms.RandomHorizontalFlip(p=1.0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
#
#######brighter
data_transform = transforms.Compose([
       transforms.ColorJitter(brightness=(1.3,1.3), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
#
##########darker
data_transform = transforms.Compose([
       transforms.ColorJitter(brightness=(0.7,0.7), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
##
##########darker_horizontal
data_transform = transforms.Compose([
       transforms.RandomHorizontalFlip(p=1.0),
       transforms.ColorJitter(brightness=(0.7,0.7), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
##
##########brighter_horizontal
data_transform = transforms.Compose([
       transforms.RandomHorizontalFlip(p=1.0),
       transforms.ColorJitter(brightness=(1.3,1.3), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
###
##########veryBright
data_transform = transforms.Compose([
       transforms.ColorJitter(brightness=(1.6,1.6), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
##
##########veryDark
data_transform = transforms.Compose([
       transforms.ColorJitter(brightness=(0.4,0.4), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
###
#########veryBright_horizontal
data_transform = transforms.Compose([
       transforms.RandomHorizontalFlip(p=1.0),
       transforms.ColorJitter(brightness=(1.6,1.6), contrast=0, saturation=0, hue=0),
       transforms.ToTensor(),                     
       transforms.Normalize(                     
           mean=[0.485, 0.456, 0.406],               
           std=[0.229, 0.224, 0.225]                  
       )])
###
##########veryDark_horizontal
data_transform = transforms.Compose([
   transforms.RandomHorizontalFlip(p=1.0),
   transforms.ColorJitter(brightness=(0.4,0.4), contrast=0, saturation=0, hue=0),
   transforms.ToTensor(),                     
   transforms.Normalize(                     
       mean=[0.485, 0.456, 0.406],               
       std=[0.229, 0.224, 0.225]                  
   )])

transformation = 'veryDark_horizontal' + '_'
path = 'C:\\Users\\Florian\\Desktop\\yale_new\\glasses_test'
#benign data
yalefaces = datasets.ImageFolder(root = 
                             path,
                             transform=data_transform)

# %%
dataset_loader_train = torch.utils.data.DataLoader(yalefaces, batch_size=1)

# %%
def getImage(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    return inp

# %%
for index, (inputs, classes) in enumerate(iter(dataset_loader_train)):
    out = torchvision.utils.make_grid(inputs)
    image = getImage(out)
    
    plt.imshow(image, interpolation='nearest')
    plt.axis("off")   # turns off axes
   
    #fix class path
    classNumber = classes.numpy()[0]
    if(classes.numpy()[0] == 0):
        classNumber = 1
    if(classes.numpy()[0] == 1):
        classNumber = 2
    if(classes.numpy()[0] == 2):
        classNumber = 3
    if(classes.numpy()[0] == 3):
        classNumber = 4
    if(classes.numpy()[0] == 4):
        classNumber = 5
    if(classes.numpy()[0] == 5):
        classNumber = 6
    if(classes.numpy()[0] == 6):
        classNumber = 7
    if(classes.numpy()[0] == 7):
        classNumber = 8
    if(classes.numpy()[0] == 8):
        classNumber = 9
    if(classes.numpy()[0] == 9):
        classNumber = 10
    if(classes.numpy()[0] == 10):
        classNumber = 11
    if(classes.numpy()[0] == 11):
        classNumber = 12
    if(classes.numpy()[0] == 12):
        classNumber = 13
    if(classes.numpy()[0] == 13):
        classNumber = 14
    if(classes.numpy()[0] == 14):
        classNumber = 15
    
    tempPath = path + '_extended\\'
    tempPath += (('0' + str(classNumber)) if classNumber < 10 else (str(classNumber))) + '/'
       
    filename = transformation + str(index) + ".png"
    total = tempPath + filename
    print(total)
    plt.savefig(total,bbox_inches='tight', pad_inches = 0)
    plt.close()
    del out
    del image
    del classNumber
    del tempPath
    del filename
    del total
# Out:
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\02/veryDark_horizontal_0.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\02/veryDark_horizontal_1.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\04/veryDark_horizontal_2.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\04/veryDark_horizontal_3.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\06/veryDark_horizontal_4.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\06/veryDark_horizontal_5.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\07/veryDark_horizontal_6.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\07/veryDark_horizontal_7.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\09/veryDark_horizontal_8.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\09/veryDark_horizontal_9.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\10/veryDark_horizontal_10.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\10/veryDark_horizontal_11.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\12/veryDark_horizontal_12.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\12/veryDark_horizontal_13.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\14/veryDark_horizontal_14.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\15/veryDark_horizontal_15.png
# C:\Users\Florian\Desktop\yale_new\glasses_test_extended\15/veryDark_horizontal_16.png
